# %%
import os

import pandas as pd
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

# %%
database_path = "sqlite:///db/olympic-history.sqlite"
    
engine = create_engine("sqlite:///db/olympic-history.sqlite")
conn = engine.connect()

# %%
# ?////////////////////////////////////////////////////////////////////////////////////////for table_name in inspect(engine).get_table_names():
    print(table_name)
# Out:
# NOC
# medals
# olympiad

# %%
data1 = pd.read_sql("SELECT * FROM olympiad", conn)
data1
# Out:
#     Year            City        Lat         Lon  Region_Count  Nations  \
# 0   1896          Athina  37.983972   23.727806            12       14
# 1   1900           Paris  48.856667    2.350833            31       28
# 2   1904       St. Louis  38.627222  -90.197778            14       12
# 3   1908          London  51.507222   -0.127500            22       22
# 4   1912       Stockholm  59.329444   18.068611            28       28
# 5   1920       Antwerpen  51.217778    4.400278            29       29
# 6   1924           Paris  48.856667    2.350833            45       44
# 7   1928       Amsterdam  52.366667    4.900000            46       46
# 8   1932     Los Angeles  34.050000 -118.250000            47       37
# 9   1936          Berlin  52.516667   13.388889            49       49
# 10  1948          London  51.507222   -0.127500            58       59
# 11  1952        Helsinki  60.170833   24.937500            66       69
# ...

# %%
data1.Year.unique()
# Out:
# array([1896, 1900, 1904, 1908, 1912, 1920, 1924, 1928, 1932, 1936, 1948,
#        1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992,
#        1996, 2000, 2004, 2008, 2012, 2016], dtype=int64)

# %%
df1= data1[data1['Year']==1988]
data1.loc[data1["Year"] == 1988, 'City'].values[0]
# data1.loc["YEAR"==1988, 'City']
# Out:
# 'Seoul'

# %%
data = {}
data1 = data1[17:]
data["Year"] = data1.Year.values.tolist()
data["Total Costs"] = data1["Total Costs"] .values.tolist()
data["Profit/Loss"] = data1["Profit/Loss"].values.tolist()
data
# Out:
# {'Year': [1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016],
#  'Total Costs': ['5100',
#   '6331',
#   '958',
#   '8200',
#   '16200',
#   '2600',
#   '6700',
#   '11500',
#   '47000',
#   '15300',
#   '12000'],
#  'Profit/Loss': ['-3200',
#   '-1190',
#   '517.3',
#   '1000',
#   '8.6',
#   '15.4',
#   '-2900',
#   '-14500',
#   '190.3',
#   '91.3',
#   '']}

# %%
data1['Year'].values.tolist()
# Out:
# [1896,
#  1900,
#  1904,
#  1908,
#  1912,
#  1920,
#  1924,
#  1928,
#  1932,
#  1936,
#  1948,
#  1952,
#  1956,
#  1960,
#  1964,
#  1968,
#  1972,
#  1976,
#  1980,
#  1984,
#  1988,
#  1992,
#  1996,
#  2000,
#  2004,
#  2008,
#  2012,
#  2016]

# %%
data2 = pd.read_sql("SELECT * FROM medals", conn)
data2.head()
# Out:
#                   YNS  Year  NOC      Sport  Gold-m  Silver-m  Bronze-m  \
# 0  1896|AUS|Athletics  1896  AUS  Athletics       2         0         0
# 1    1896|AUT|Cycling  1896  AUT    Cycling       1         0         2
# 2    1896|AUT|Fencing  1896  AUT    Fencing       0         0         0
# 3   1896|AUT|Swimming  1896  AUT   Swimming       1         1         0
# 4  1896|DEN|Athletics  1896  DEN  Athletics       0         0         0
#
#    #Entries-m  Gold-w  Silver-w  Bronze-w  #Entries-w  Gold-x  Silver-x  \
# 0           3       0         0         0           0       0         0
# 1           4       0         0         0           0       0         0
# 2           1       0         0         0           0       0         0
# 3           3       0         0         0           0       0         0
# 4           4       0         0         0           0       0         0
#
#    Bronze-x  #Entries-x
# 0         0           0
# 1         0           0
# ...

# %%
data2.Sport.unique()
# Out:
# array(['Athletics', 'Cycling', 'Fencing', 'Swimming', 'Gymnastics',
#        'Weightlifting', 'Rowing', 'Diving'], dtype=object)

# %%
data2['madels_count']=
